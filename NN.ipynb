# %%
from tensorflow import keras
from sklearn.neural_network import MLPClassifier
from keras.datasets import mnist 
import matplotlib.pyplot as plt 
import numpy as np
import random
import joblib

# Load and normalize data
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalization
x_train = x_train / 255 
x_test = x_test / 255

# Flatten 28x28 images into 784 features
x_train_flat = x_train.reshape((x_train.shape[0], -1))
x_test_flat = x_test.reshape((x_test.shape[0], -1))

# Build and train the model
# One hidden layer (100 neurons) with max iters = 20 and verbose (print loss after each iteration)
model = MLPClassifier(hidden_layer_sizes=(100,), max_iter=1000, verbose=True) 
model.fit(x_train_flat, y_train)


# Evaluate accuracy
accuracy = model.score(x_test_flat, y_test)
print(f"Test Accuracy: {accuracy * 100:.2f}%")

joblib.dump(model, 'D:/ANU/Year 2/Second Term/Machine Learning/Assignments/2/mlp_model.pkl')

# Predict a random image
index = random.randint(0, len(x_test_flat) - 1)
image = x_test[index]
true_label = y_test[index]
predicted_label = model.predict([x_test_flat[index]])

# Show result
plt.imshow(image, cmap='gray')
plt.title(f"Predicted: {predicted_label[0]}, True: {true_label}")
plt.axis('off')
plt.show()
# Out:
# Iteration 1, loss = 0.45325520
# Iteration 2, loss = 0.20841089
# Iteration 3, loss = 0.15559347
# Iteration 4, loss = 0.12489822
# Iteration 5, loss = 0.10283376
# Iteration 6, loss = 0.08798029
# Iteration 7, loss = 0.07563428
# Iteration 8, loss = 0.06536601
# Iteration 9, loss = 0.05744805
# Iteration 10, loss = 0.05131711
# Iteration 11, loss = 0.04487218
# Iteration 12, loss = 0.04037911
# Iteration 13, loss = 0.03602794
# Iteration 14, loss = 0.03151513
# Iteration 15, loss = 0.02872775
# Iteration 16, loss = 0.02575478
# Iteration 17, loss = 0.02231098
# Iteration 18, loss = 0.02062345
# Iteration 19, loss = 0.01818099
# Iteration 20, loss = 0.01582761
# Iteration 21, loss = 0.01494680
# Iteration 22, loss = 0.01360104
# Iteration 23, loss = 0.01147570
# Iteration 24, loss = 0.01050675
# Iteration 25, loss = 0.00881396
# Iteration 26, loss = 0.00830295
# Iteration 27, loss = 0.00771098
# Iteration 28, loss = 0.00670334
# Iteration 29, loss = 0.00574238
# ...
